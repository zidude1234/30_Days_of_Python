# %%
#Day TwentyFive of the 30 Day Challenge
# Introduction
# Author: dataBio
# Date: 07 Mar 2022
# IDE: Jupyter Notebook

import pandas as pd

def p(num):
    print(f"Number {num}")
def bannergreeting(day_name,exercise_name):
    daybanner = f'Exercise {day_name} '
    exercisebanner = f'Level {exercise_name} '
    front_end = f'--' * 20
    return combinebanners(front_end,daybanner,exercisebanner)
  
def combinebanners(s0,s1,s2):
    return s0 + s1 + s2 + s0

banner = bannergreeting


print(banner(25,1))
#1 Read the hacker_news.csv file from data directory
p(1)
hk = pd.read_csv('data/hacker_news.csv')
print("=============Hacker News Info===============")
print(hk.info())
print("=============Hacker News Shape===============")
print(hk.shape)
print('\n'*2)
#2 Get the first five rows
p(2)
print("=============Hacker News DataFrame (First 5 Rows)===============")
print(hk.head(5))
print('\n'*2)
#3 Get the last five rows
p(3)
print("=============Hacker News DataFrame (Last 5 Rows)===============")
print(hk.tail(5))
print('\n'*2)
#4 Get the title column as pandas series
p(4)
print("=============Title as a pandas series===============")
Title = hk['title'] 
print(Title)
print('\n'*2)
#Count the number of rows and columns
p(5)
print(f"Number of rows: {(hk.shape)[0]} and Columns: {(hk.shape)[1]}")
print('\n'*1)
#Filter the titles which contain python
print(hk[hk["title"].str.contains('python')])
print('\n'*1)
#Filter the titles which contain Javascript
print(hk[hk["title"].str.contains('javascript')])
print('\n'*1)
#Explore the data and make sense of it
print(hk.describe())
# Out:
# ----------------------------------------Exercise 25 Level 1 ----------------------------------------
# Number 1
# =============Hacker News Info===============
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20099 entries, 0 to 20098
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20099 non-null  int64
#  1   title         20099 non-null  object
#  2   url           17659 non-null  object
#  3   num_points    20099 non-null  int64
#  4   num_comments  20099 non-null  int64
#  5   author        20099 non-null  object
#  6   created_at    20099 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 1.1+ MB
# None
# =============Hacker News Shape===============
# (20099, 7)
#
#
#
# Number 2
# =============Hacker News DataFrame (First 5 Rows)===============
#          id                                              title  \
# ...
